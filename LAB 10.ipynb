# %% [markdown]
# #9. a. Functions are objects

# %%
def shout(text):
  return text.upper()
  print (shout("hello"))
  yell=shout
  print(yell("world"))

# %% [markdown]
# #9. b. Functions can be passed as arguments to other functions (higher-order function)

# %%
def shout(text):
  return text.upper()
def whisper(text):
  return text.lower()
def greet():
  greeting=function("hello")
  print(greeting)
  greet(shout)
  greet(whisper)

# %% [markdown]
# #9. c. Functions can return another function

# %%
def create_adder(x):
  def adder(y):
    return x+y
  return adder
  add_6=create_adder(6)
  print(add_6)
  print(add_6(10))

# %% [markdown]
# #9. d. Map() Function

# %%
map(function,sequences)
    def mul_(2(n))
    return n*2
    number= (1,2,3,4)
    result=map(num_2,number)
    print(list(result))

# %% [markdown]
# #9. e. Reduce() Function

# %%
import operator
import functions
lists=[1,3,5,6,2]
print("sum")
print(functools.reduce(operator.add,lists))
print(functools.reduce(lambda a,b:a+b,lists))
print("Max")
print(functools.reduce(lambda a,b:a if a>b else b,list))

# %% [markdown]
# #9. f. Filter() Function

# %%
filter(function,sequence)
def fun(variable)
 letters=['a','e','i','o','u']
 if (variable in letters)
 return True
 else
 return False
 sequence=["e","d","u","c","a","t","i","o","n"]
 filtered=filter(function,sequence)
for s in filtered
print(s)
