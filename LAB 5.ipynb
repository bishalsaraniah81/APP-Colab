# %% [markdown]
# PROGRAM 1 - GRATUITY COMPUTATION

# %%
Ids=int(input("last drawn salary: "))
wt=int(input("working tenure: "))
gratuity=(15*Ids*wt)/30
print(gratuity)
# Out:
# last drawn salary: 10000
# working tenure: 7
# 35000.0

# %% [markdown]
# PROGRAM 2 - FIND THE TWO HIGHEST SCORES

# %%
scores=eval(input("Enter the scores: "))
scores.sort()
print("Highest: ",scores[-1],"second highest: ",scores[-2])
# Out:
# Enter the scores: [21,52,81,70]
# Highest:  81 second highest:  70

# %% [markdown]
# PROGRAM 3 - CONVERT DECIMAL INTO BINARY

# %%
def DecimalToBinary(num):   
    if num >= 1:
        DecimalToBinary(num // 2)
    print(num % 2, end = '')
if __name__ == '__main__':
    dec_val = 4
    DecimalToBinary(dec_val)
# Out:
# 0100

# %% [markdown]
# PROGRAM 4 - FIND LCM OF 2 NUMBERS

# %%
def compute_lcm(x, y):
   if x > y:
       greater = x
   else:
       greater = y

   while(True):
       if((greater % x == 0) and (greater % y == 0)):
           lcm = greater
           break
       greater += 1
   return lcm

num1 = 3
num2 = 4

print("The L.C.M. is", compute_lcm(num1, num2))
# Out:
# The L.C.M. is 12

# %% [markdown]
# PROGRAM 5 - FIND WHETHER THE GIVEN NUMBER IS ARMSTRONG NUMBER

# %%
num = int(input("Enter a number: "))
sum = 0
temp = num
while temp > 0:
   digit = temp % 10
   sum += digit ** 3
   temp //= 10
if num == sum:
   print(num,"is an Armstrong number")
else:
   print(num,"is not an Armstrong number")
# Out:
# Enter a number: 555
# 555 is not an Armstrong number

# %% [markdown]
# PROGRAM 6 - FIND THE AREA OF THE TRIANGLE

# %%
a=float(input('enter the first side'))
b=float(input('enter the second side'))
c=float(input('enter the third side'))
s=(a+b+c)/2
area=(s*(s-a)*(s-b)*(s-c))**0.5
print('the area of the triangle is %0.2f'%area)
# Out:
# enter the first side10
# enter the second side11
# enter the third side12
# the area of the triangle is 51.52

# %% [markdown]
# PROGRAM 7 - FIND THE SIMPLE INTEREST

# %%
def simple_interest(p,t,r):
    print('The principal is', p)
    print('The time period is', t)
    print('The rate of interest is',r)
    si = (p * t * r)/100
    print('The Simple Interest is', si)
    return si
simple_interest(8, 6, 8)
# Out:
# The principal is 8
# The time period is 6
# The rate of interest is 8
# The Simple Interest is 3.84
# 3.84

# %% [markdown]
# PROGRAM 8 - SOLVE QUADRATIC EQUATION ax^2 + bx + c

# %%
import cmath
a=float(input('enter a:'))
b=float(input('enter b:'))
c=float(input('enter c:'))
d=(b**2)-(4*a*c)
sol1=(-b-cmath.sqrt(d))/(2*a)
sol2=(-b+cmath.sqrt(d))/(2*a)
print('the solution are',sol1,sol2)
# Out:
# enter a:2
# enter b:6
# enter c:3
# the solution are (-2.3660254037844384+0j) (-0.6339745962155614+0j)
