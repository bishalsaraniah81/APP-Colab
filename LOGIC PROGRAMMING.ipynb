# %%
from kanren import run,var,fact
from kanren.assoccomm import eq_assoccomm as eq
from kanren.assoccomm import commutative, associative
add=' add'
mul= 'mul '
fact (commutative, mul)
fact (commutative, add)
fact(associative,mul)
fact (associative, add)
 
a = var('a')
b = var('b')
pattern=(add, (mul, 2, a, b), b)
exprl=(add, (mul, 2, 1, 2) , 2)
expr2=(add,3,(mul,2,1,3))
expr3=(add,3,(mul,2,3,1))
print ( run (0, (a, b) , eq (exprl, pattern)))
print (run (0, (a, b) , eq (expr2, pattern)))
print (run (0, (a, b) , eq (expr3, pattern)))
# Out:
# ((1, 2), (1, 2), (1, 2), (1, 2), (1, 2), (1, 2))
# ((1, 3), (1, 3))
# ((1, 3),)

# %%
from sympy import *
x = sympify(true)
print(x)
# Out:
# True

# %%
from sympy import S
expr = S.false
print(expr)
# Out:
# False

# %%
from sympy.logic.boolalg import And
x,y = symbols('x y')
x = true
Y = true
print(And(x,y))
# Out:
# y

# %%
# !pip install pyDatalog
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 24.1 MB/s eta 0:00:00
# ...

# %%
from pyDatalog import pyDatalog
pyDatalog. create_terms(' Bear , Elephant , Cat , Black, Gray , light, Brown , Big, small, size, color , X, Y , dark ' )
+size("Bear", "Big")
+size( "Elephant" , "Big")
+size("cat", "small")
+color( " Bear" , "Brown")
+color( "Cat" , "Black")
+color("elephant","Gray")
dark(X)<=(color(X,"Black" ))
dark(X)<=(color(X,"Brown"))
light(X)<=(color(X, "Gray"))
print(light(X)&(size(X,'Big')))
# Out:
# []

# %%
from sympy import symbols, Not
x, y = symbols('x y')
expr = Not(x & y)
print(expr)
# Out:
# ~(x & y)

# %%
from sympy import symbols, Xor
x, y = symbols('x y')
expr = Xor(x, y)
print(expr)
# Out:
# x ^ y

# %%
from sympy import symbols, Nand
x, y = symbols('x y')
expr = Nand(x, y)
print(expr)
# Out:
# ~(x & y)

# %%
from sympy import symbols, Nor
x, y = symbols('x y')
expr = Nor(x, y)
print(expr)
# Out:
# ~(x | y)
