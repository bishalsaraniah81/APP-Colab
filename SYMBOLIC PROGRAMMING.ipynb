# %%
# !pip install SymPy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from sympy import *
a=Rational(5,8)
print("Value of a is "+str(a))
b=Integer(3.579)
print("Value of b is "+str(b))
# Out:
# Value of a is 5/8
# Value of b is 3

# %%
p=pi**3
print("Value of p is "+str(p))
q=pi.evalf()
print("Value of q is "+str(q))
# Out:
# Value of p is pi**3
# Value of q is 3.14159265358979

# %%
r=exp(1).evalf()
print("Value of r is "+str(r))
s=(pi + exp(1)).evalf()
print("Value of s is "+str(s))
t=oo + 10000
print("Value of t is "+str(t))
if oo > 999999:
  print("True")
else:
  print("False")
# Out:
# Value of r is 2.71828182845905
# Value of s is 5.85987448204884
# Value of t is oo
# True

# %%
x=Symbol('x')
y=Symbol('y')
z=(x+y) + (x-y)
print("Value of z is "+str(z))
# Out:
# Value of z is 2*x

# %%
a=expand((x+y)**2)
b=3*x*y**2+3*y*x**2+x**3+y**3
print(a)
print(b)
expand(cos(x+y), trig=True)
# Out:
# x**2 + 2*x*y + y**2
# x**3 + 3*x**2*y + 3*x*y**2 + y**3
# -sin(x)*sin(y) + cos(x)*cos(y)

# %%
expand(x+y, complex=True)
I*im(x) + I*im(y) + re(x) + re(y)
# Out:
# re(x) + re(y) + I*im(x) + I*im(y)

# %%
simplify((x+x*y)/x)
# Out:
# y + 1

# %%
limit(sin(x)/x,x,0)
# Out:
# 1

# %%
limit(x,x,oo)
# Out:
# oo

# %%
limit(x**x,x,0)
# Out:
# 1

# %%
diff(sin(x),x)
# Out:
# cos(x)

# %%
diff(sin(2*x),x)
# Out:
# 2*cos(2*x)

# %%
diff(tan(x),x)
# Out:
# tan(x)**2 + 1

# %%
series(1/cos(x),x)
# Out:
# 1 + x**2/2 + 5*x**4/24 + O(x**6)

# %%
integrate(6*x**5,x)
# Out:
# x**6

# %%
solveset(x**4-1,x)
# Out:
# {-1, 1, -I, I}

# %%
solveset(exp(x)+1,x)
# Out:
# ImageSet(Lambda(_n, I*(2*_n*pi + pi)), Integers)

# %%
solution =solve((x+5*y-2,-3*x+6*y-15),(x,y))
solution[x],solution[y]
# Out:
# (-3, 1)

# %%
f=x**4-3*x**2+1
factor(f)
# Out:
# (x**2 - x - 1)*(x**2 + x - 1)

# %%
satisfiable(x&y)
# Out:
# {x: True, y: True}

# %%
Matrix([[0,1],[1,0]])
# Out:
# Matrix([
# [0, 1],
# [1, 0]])

# %%
A=Matrix([[1,x],[y,1]])
A
# Out:
# Matrix([
# [1, x],
# [y, 1]])

# %%
A**2
# Out:
# Matrix([
# [x*y + 1,     2*x],
# [    2*y, x*y + 1]])

# %%
f,g=symbols('f g',cls=Function)

# %%
dsolve(f(x).diff(x,x) + f(x),f(x))
# Out:
# Eq(f(x), C1*sin(x) + C2*cos(x))

# %% [markdown]
# #13a. Write a program to Expand the expression (x+y) 3 and complex expression (x+y)

# %%
a=expand((x+y)**3)
b=expand(x+y,complex=True)
print(a)
print(b)
# Out:
# x**3 + 3*x**2*y + 3*x*y**2 + y**3
# re(x) + re(y) + I*im(x) + I*im(y)

# %% [markdown]
# #13b. Write a program to Perform matrix operation

# %%
A=Matrix([[3,5],[4,6]])
B=Matrix([[2,1],[3,2]])
A+B
# Out:
# Matrix([
# [5, 6],
# [7, 8]])
