# %% [markdown]
# PROGRAM 1

# %%
a = [3,5,2,9,7,6]
sum = 0
for i in a:
  sum += i
print(sum)
# Out:
# 32

# %% [markdown]
# PROGRAM 2

# %%
def split(num):
  even = []
  odd = []
  for i in num:
    if(i%2 == 0):
      even.append(i)
    else:
      odd.append(i)
  print("Even Lists : ",even)
  print("Odd Lists : ",odd)

num = [1, 5, 13, 22, 51, 73, 66]
split(num)
# Out:
# Even Lists :  [22, 66]
# Odd Lists :  [1, 5, 13, 51, 73]

# %% [markdown]
# PROGRAM 3

# %%
def name(*arg):
  for i in arg:
    print(i)

list=[]
i='-1'
while(i!='0'):
  i=(input())
  list.append(i)
  name(list)
# Out:
# 0
# ['0']

# %% [markdown]
# PROGRAM 4

# %%
def add(num1, num2):
    return num1 + num2
def sub(num1, num2):
    return num1 - num2
def mul(num1, num2):
    return num1 * num2
def div(num1, num2):
    return num1 / num2
 
print("Please select operation -\n" \
        "1. Add\n" \
        "2. Subtract\n" \
        "3. Multiply\n" \
        "4. Divide\n")
select = int(input("Select operations (Add / Sub / Mul / Div) :"))
 
number_1 = int(input("Enter first number: "))
number_2 = int(input("Enter second number: "))
 
if select == 1:
    print(number_1, "+", number_2, "=",
                    add(number_1, number_2))
 
elif select == 2:
    print(number_1, "-", number_2, "=",
                    sub(number_1, number_2))
 
elif select == 3:
    print(number_1, "*", number_2, "=",
                    mul(number_1, number_2))
 
elif select == 4:
    print(number_1, "/", number_2, "=",
                    div(number_1, number_2))
else:
    print("Invalid input")
# Out:
# Please select operation -
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
#
# Select operations (Add / Sub / Mul / Div) :2
# Enter first number: 2
# Enter second number: 1
# 2 - 1 = 1

# %% [markdown]
# PROGRAM 5

# %%
def linear_Search(list1, n, key):  
  
    # Searching list1 sequentially  
    for i in range(0, n):  
        if (list1[i] == key):  
            return i  
    return -1  
  
  
list1 = [1 ,3, 5, 4, 7, 9]  
key = 7  
  
n = len(list1)  
res = linear_Search(list1, n, key)  
if(res == -1):  
    print("Element not found")  
else:  
    print("Element found at index: ", res)
# Out:
# Element found at index:  4
